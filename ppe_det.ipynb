# %% [markdown]
# # 🦺 PPE Detection using YOLOv8
# *Personal Protective Equipment Detection using Deep Learning*
#
# This notebook demonstrates how to **train, validate, and test** a YOLOv8 model for detecting PPE items such as **helmets, vests, gloves, and boots**.
# Developed as part of a computer vision project focused on **workplace safety monitoring** using real-time object detection.
#
# ---
#
# ### 📘 Features
# - ✅ Detects multiple PPE items
# - ⚡ Trained using [Ultralytics YOLOv8](https://github.com/ultralytics/ultralytics)
# - 🧠 Custom dataset support
# - 🎥 Real-time inference using webcam or video
# - 📊 Visualized training metrics and detection results

# %% [markdown]
# ##Verify GPU (Optional)

# %%
# !nvidia-smi
# Out:
# Thu Oct  2 08:45:06 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ##Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Install Dependencies

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=predict model=yolov8l.pt source="https://ultralytics.com/images/bus.jpg"

# %% [markdown]
# ## Model training

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/drive/MyDrive/Datasets/PPE/data.yaml epochs=50 imgsz=640 project=/content/drive/MyDrive/yolo_runs name=ppe_train
# Out:
# ...
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results_path = "/content/drive/MyDrive/ppe_training_results/ppe_detection_model"
print(f"Training results saved to: {results_path}")

# Display results graph
from IPython.display import Image, display
display(Image(filename=f"{results_path}/results.png"))

# %% [markdown]
# Trained model will be saved to the drive. Download and use the best.py from your drive and use it in the main.py file for good functionality.

# %% [markdown]
# # ✅ Conclusion
#
# This notebook successfully demonstrates **PPE detection using YOLOv8** on a custom dataset.
#
# ### Key Outcomes:
# - Trained YOLOv8 model on a labeled PPE dataset
# - Evaluated performance and visualized results
# - Generated a deployable `.pt` model for inference
#
# ### 🚀 Next Steps:
# - Integrate model with live camera or CCTV feeds
# - Deploy using Flask or FastAPI web server
# - Add alert system for missing PPE detections
#
# ---
#
# **Author:** Rama Sravan Gunda
# *University of Limerick | MSc Computer Vision and AI*
# 📧 ramasravan7@gmail.com
